# %%
import pandas as pd
import os
print(os.getcwd())
# Out:
# c:\Users\rayan\Desktop\AI Projects\Titanic Project

# %%
Titanic_Data = pd.read_csv(r"c:\Users\rayan\Desktop\AI Projects\Titanic Project\Titanic_Data.csv")
